# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['AR PL UMing CN']

# %% [markdown]
# ## 矩阵分解模型

# %%
xpoints = [16, 32, 64, 128]
precision5 = [0.2828, 0.2966, 0.2913, 0.3092]
recall5 = [0.0608, 0.0660, 0.0670, 0.0746]
ndcg5 = [0.2889, 0.3110, 0.3027, 0.3291]
precision10 = [0.2481, 0.2532, 0.2512, 0.2564]
recall10 = [0.1053, 0.1094, 0.1126, 0.1174]
ndcg10 = [0.2686, 0.2829, 0.2779, 0.2949]

fig,axs = plt.subplots(nrows=1, ncols=3, figsize=(20,6), dpi=100)
ydatas = [(precision5, precision10), (recall5, recall10), (ndcg5, ndcg10)]
colors = [('blue','cyan'), ('green','magenta'), ('red', 'yellow')]
line_styles = ['-', '--', '-.']
y_labels = [('precision@5', 'precision@10'), ('recall@5', 'recall@10'), ('ndcg@5', 'ndcg@10')]
y_label = ['precision', 'recall', 'ndcg']
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for i in range(3):
    axs[i].plot(xpoints, ydatas[i][0], c=colors[i][0], label=y_labels[i][0], linestyle=line_styles[i])
    axs[i].plot(xpoints, ydatas[i][1], c=colors[i][1], label=y_labels[i][1], linestyle=line_styles[i])
    axs[i].scatter(xpoints, ydatas[i][0], c=colors[i][0])
    axs[i].scatter(xpoints, ydatas[i][1], c=colors[i][1])
    axs[i].legend(loc='best')
    axs[i].grid(True, linestyle='--', alpha=0.5)
    axs[i].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[i].set_ylabel(y_label[i], fontdict={'size': 12}, rotation=90)
    axs[i].set_title(titles[i])
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ## 图谱嵌入模型

# %%
## plus+multitask
xpoints = [16, 32, 64, 128]
precision5E = [0.2864, 0.3011, 0.3083, 0.3226]
precision5R = [0.2872, 0.2922, 0.2908, 0.3020]
precision10E = [0.2604, 0.2557, 0.2633, 0.2787]
precision10R = [0.2541, 0.2544, 0.2588, 0.2544]

recall5E = [0.0611, 0.0672, 0.0711,0.0775]
recall5R = [0.0636, 0.0699, 0.0682, 0.0727]
recall10E = [0.1099, 0.1127, 0.1206, 0.1310]
recall10R = [0.1106, 0.1161, 0.1174, 0.1172]

ndcg5E = [0.2971, 0.3183, 0.3160, 0.3445]
ndcg5R = [0.2973, 0.3082, 0.3091, 0.3226]
ndcg10E = [0.2816, 0.2881, 0.2898, 0.3171]
ndcg10R = [0.2770, 0.2853, 0.2881, 0.2915]


fig,axs = plt.subplots(nrows=3, ncols=2, figsize=(20,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [('precision@5', 'precision@10'), ('recall@5', 'recall@10'), ('ndcg@5', 'ndcg@10')]
y_label = ('precision', 'recall', 'ndcg')
titles = [['TransE下嵌入维度对precision的影响', 'TransR下嵌入维度对precision的影响'], ['TransE下嵌入维度对recall的影响', 'TransR下嵌入维度对recall的影响'], ['TransE下嵌入维度对ndcg的影响', 'TransR下嵌入维度对ndcg的影响']]

for j in range(3):
    for i in range(2):
        axs[j][i].plot(xpoints, ydatas[j][i][0], c=colors[i][0], label=y_labels[j][0], linestyle=line_styles[i])
        axs[j][i].plot(xpoints, ydatas[j][i][1], c=colors[i][1], label=y_labels[j][1], linestyle=line_styles[i])
        axs[j][i].scatter(xpoints, ydatas[j][i][0], c=colors[i][0])
        axs[j][i].scatter(xpoints, ydatas[j][i][1], c=colors[i][1])
        axs[j][i].legend(loc='best')
        axs[j][i].grid(True, linestyle='--', alpha=0.5)
        axs[j][i].set_xlabel("embed_dim", fontdict={'size': 12})
        axs[j][i].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
        axs[j][i].set_title(titles[j][i])
fig.autofmt_xdate()
plt.show()

# %%
## plus+multitask
xpoints = [16, 32, 64, 128]
precision5E = [0.2864, 0.3011, 0.3083, 0.3226]
precision5R = [0.2872, 0.2922, 0.2908, 0.3020]
precision10E = [0.2604, 0.2557, 0.2633, 0.2787]
precision10R = [0.2541, 0.2544, 0.2588, 0.2544]

recall5E = [0.0611, 0.0672, 0.0711,0.0775]
recall5R = [0.0636, 0.0699, 0.0682, 0.0727]
recall10E = [0.1099, 0.1127, 0.1206, 0.1310]
recall10R = [0.1106, 0.1161, 0.1174, 0.1172]

ndcg5E = [0.2971, 0.3183, 0.3160, 0.3445]
ndcg5R = [0.2973, 0.3082, 0.3091, 0.3226]
ndcg10E = [0.2816, 0.2881, 0.2898, 0.3171]
ndcg10R = [0.2770, 0.2853, 0.2881, 0.2915]



fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## mul+multitask
xpoints = [16, 32, 64, 128]

precision5R = [0.2823, 0.1383, 0.0456, 0.0814]
precision10R = [0.2438, 0.1145, 0.0497, 0.0685]
recall5R = [0.0653, 0.0287, 0.0115, 0.0211]
recall10R = [0.1049, 0.0487, 0.024, 0.033]
ndcg5R = [0.2967, 0.1497, 0.0443, 0.0931]
ndcg10R = [0.2715, 0.1318, 0.0489, 0.083]
precision5E = [0.2984, 0.2859, 0.2899, 0.3065]
precision10E = [0.2584, 0.2499, 0.2526, 0.262]
recall5E = [0.067, 0.0637, 0.0657, 0.0686]
recall10E = [0.1158, 0.1111, 0.114, 0.1186]
ndcg5E = [0.3063, 0.3022, 0.3028, 0.32]
ndcg10E = [0.2822, 0.2786, 0.2797, 0.2922]


fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## concat+multitask

xpoints = [16, 32, 64, 128]

precision5R = [0.2868, 0.2917, 0.2908, 0.302]
precision10R = [0.2541, 0.2544, 0.2584, 0.2544]
recall5R = [0.0635, 0.0695, 0.0682, 0.0727]
recall10R = [0.1107, 0.1161, 0.1173, 0.1172]
ndcg5R = [0.297, 0.308, 0.3088, 0.3226]
ndcg10R = [0.277, 0.2853, 0.2876, 0.2915]
precision5E = [0.2864, 0.3007, 0.3038, 0.3221]
precision10E = [0.2604, 0.2555, 0.2638, 0.2787]
recall5E = [0.0611, 0.0671, 0.0714, 0.0774]
recall10E = [0.1099, 0.1127, 0.1192, 0.131]
ndcg5E = [0.2971, 0.3181, 0.3188, 0.3443]
ndcg10E = [0.2816, 0.288, 0.2932, 0.3171]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## plus+iteration

xpoints = [16, 32, 64, 128]

precision5R = [0.2926, 0.294, 0.2864, 0.3056]
precision10R = [0.2539, 0.2568, 0.2483, 0.264]
recall5R = [0.0638, 0.0676, 0.0663, 0.0711]
recall10R = [0.1094, 0.115, 0.1132, 0.1217]
ndcg5R = [0.3032, 0.3091, 0.3044, 0.3241]
ndcg10R = [0.2786, 0.286, 0.2798, 0.2981]
precision5E = [0.2899, 0.2966, 0.3114, 0.3221]
precision10E = [0.2515, 0.2655, 0.2676, 0.2787]
recall5E = [0.0654, 0.0678, 0.0733, 0.0772]
recall10E = [0.1104, 0.1173, 0.1213, 0.1299]
ndcg5E = [0.2977, 0.315, 0.3246, 0.3479]
ndcg10E = [0.2751, 0.2946, 0.2974, 0.3197]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## mul+iteration

xpoints = [16, 32, 64, 128]

precision5R = [0.2917, 0.111, 0.1248, 0.043]
precision10R = [0.2508, 0.0944, 0.1081, 0.0485]
recall5R = [0.0667, 0.022, 0.0269, 0.0116]
recall10R = [0.112, 0.038, 0.0453, 0.0234]
ndcg5R = [0.3033, 0.1142, 0.1303, 0.0417]
ndcg10R = [0.278, 0.1029, 0.119, 0.0478]
precision5E = [0.3007, 0.2837, 0.2805, 0.3119]
precision10E = [0.257, 0.249, 0.2588, 0.268]
recall5E = [0.0683, 0.0635, 0.0638, 0.0706]
recall10E = [0.1158, 0.1101, 0.1136, 0.1202]
ndcg5E = [0.3087, 0.2899, 0.2991, 0.3258]
ndcg10E = [0.2826, 0.2705, 0.2843, 0.2981]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## concat+iteration

xpoints = [16, 32, 64, 128]

precision5R = [0.2931, 0.3074, 0.285, 0.306]
precision10R = [0.2539, 0.2591, 0.2497, 0.264]
recall5R = [0.0643, 0.0682, 0.0666, 0.0712]
recall10R = [0.1094, 0.1132, 0.1112, 0.1217]
ndcg5R = [0.3035, 0.3215, 0.2991, 0.3244]
ndcg10R = [0.2787, 0.2898, 0.2767, 0.2981]
precision5E = [0.2904, 0.2971, 0.3114, 0.3217]
precision10E = [0.2517, 0.2658, 0.2678, 0.279]
recall5E = [0.0654, 0.0679, 0.0733, 0.0771]
recall10E = [0.1105, 0.1174, 0.1214, 0.13]
ndcg5E = [0.298, 0.3153, 0.3245, 0.3475]
ndcg10E = [0.2752, 0.2946, 0.2975, 0.3197]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度对precision的影响', '嵌入维度对recall的影响', '嵌入维度对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
xpoints = ['plus+multitask',]+ ['mul+multitask',]+ ['concat+multitask',]+ ['plus+iteration',]+ ['mul+iteration',]+ ['concat+iteration',]
colors = ['blue','cyan', 'green','magenta', 'red', 'yellow']
ypoints_precision = [[0.2604, 0.2557, 0.2633, 0.2787], [0.2584, 0.2499, 0.2526, 0.262],[0.2604, 0.2555, 0.2638, 0.2787],[0.1104, 0.1173, 0.1213, 0.1299],[0.257, 0.249, 0.2588, 0.268],[0.2517, 0.2658, 0.2678, 0.279]]
ypoints_precision_max = [max(i) for i in ypoints_precision]
ypoints_recall = [[0.1099, 0.1127, 0.1206, 0.1310], [0.1158, 0.1111, 0.114, 0.1186],[0.1099, 0.1127, 0.1192, 0.131],[0.1104, 0.1173, 0.1213, 0.1299], [0.1158, 0.1101, 0.1136, 0.1202],[0.1105, 0.1174, 0.1214, 0.13]]
ypoints_recall_max = [max(i) for i in ypoints_recall]
ypoints_ndcg = [[0.2816, 0.2881, 0.2898, 0.3171], [0.2822, 0.2786, 0.2797, 0.2922],[0.2816, 0.288, 0.2932, 0.3171],[0.2751, 0.2946, 0.2974, 0.3197],[0.2826, 0.2705, 0.2843, 0.2981],[0.2752, 0.2946, 0.2975, 0.3197]]
ypoints_ndcg_max = [max(i) for i in ypoints_ndcg]
ypoints = [ypoints_precision, ypoints_recall, ypoints_ndcg]
ypoints_max = [ypoints_precision_max, ypoints_recall_max, ypoints_ndcg_max]
y_label = ('precision', 'recall', 'ndcg')
titles = ['不同训练组合方式对precision影响的对比', '不同训练组合方式对recall影响的对比', '不同训练组合方式对ndcg影响的对比']
fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
for i in range(3):
    for j in range(6):
        xpoint = [xpoints[j]]*4
        axs[i].scatter(xpoint, ypoints[i][j], c=colors[j])
    for (s,t) in zip(xpoints, ypoints_max[i]):
        axs[i].text(s, t, t, ha='center', va='bottom', fontsize=10)
    axs[i].grid(True, linestyle='--', alpha=0.5)
    axs[i].set_xlabel("不同训练组合方式", fontdict={'size': 12})
    axs[i].set_ylabel(y_label[i], fontdict={'size': 12}, rotation=90)
    axs[i].set_title(titles[i])
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ## GNN模型

# %%
## random-walk+gcn

xpoints = ['32+2layer', '64+2layer', '32+4layer', '64+4layer',]

precision5R = [0.3172, 0.3315, 0.3128, 0.3083]
precision10R = [0.2743, 0.2839, 0.2718, 0.272]
recall5R = [0.0762, 0.0824, 0.0746, 0.074]
recall10R = [0.1269, 0.1368, 0.1266, 0.1274]
ndcg5R = [0.3349, 0.3445, 0.3296, 0.3226]
ndcg10R = [0.3087, 0.3184, 0.3049, 0.303]
precision5E = [0.3302, 0.3387, 0.3298, 0.3105]
precision10E = [0.2734, 0.2935, 0.2794, 0.2736]
recall5E = [0.0773, 0.0812, 0.081, 0.0777]
recall10E = [0.1255, 0.1342, 0.1342, 0.1284]
ndcg5E = [0.3449, 0.3517, 0.3384, 0.3285]
ndcg10E = [0.3096, 0.3259, 0.3114, 0.3075]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度+中间层数对precision的影响', '嵌入维度+中间层数对recall的影响', '嵌入维度+中间层数对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## random-walk+graphsage

xpoints = ['32+2layer', '64+2layer', '32+4layer', '64+4layer',]

precision5R = [0.3217, 0.3208, 0.3186, 0.3096]
precision10R = [0.2761, 0.281, 0.2702, 0.2653]
recall5R = [0.0756, 0.0759, 0.0769, 0.0729]
recall10R = [0.1266, 0.1306, 0.124, 0.1229]
ndcg5R = [0.3388, 0.3336, 0.332, 0.3231]
ndcg10R = [0.3104, 0.311, 0.3031, 0.2972]
precision5E = [0.3289, 0.3369, 0.3199, 0.3154]
precision10E = [0.2848, 0.294, 0.2792, 0.279]
recall5E = [0.0795, 0.0795, 0.0802, 0.0774]
recall10E = [0.1328, 0.1373, 0.1316, 0.1297]
ndcg5E = [0.346, 0.3464, 0.3409, 0.3268]
ndcg10E = [0.3195, 0.3231, 0.3157, 0.3083]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度+中间层数对precision的影响', '嵌入维度+中间层数对recall的影响', '嵌入维度+中间层数对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## random-walk+lightgcn

xpoints = ['32+2layer', '64+2layer', '32+4layer', '64+4layer',]

precision5R = [0.3244, 0.3333, 0.3074, 0.2908]
precision10R = [0.2799, 0.2814, 0.2667, 0.2593]
recall5R = [0.0771, 0.0809, 0.0745, 0.07]
recall10R = [0.1291, 0.1313, 0.1259, 0.1208]
ndcg5R = [0.3354, 0.349, 0.3179, 0.3012]
ndcg10R = [0.3102, 0.3182, 0.2959, 0.2849]
precision5E = [0.3351, 0.34, 0.3204, 0.3083]
precision10E = [0.2855, 0.294, 0.2828, 0.2622]
recall5E = [0.081, 0.0822, 0.0782, 0.0747]
recall10E = [0.1335, 0.1381, 0.1334, 0.1213]
ndcg5E = [0.3535, 0.3545, 0.3311, 0.319]
ndcg10E = [0.3231, 0.3279, 0.3118, 0.293]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度+中间层数对precision的影响', '嵌入维度+中间层数对recall的影响', '嵌入维度+中间层数对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## symmetric+gcn

xpoints = ['32+2layer', '64+2layer', '32+4layer', '64+4layer',]

precision5R = [0.319, 0.302, 0.2989, 0.2931]
precision10R = [0.2694, 0.2653, 0.2642, 0.2506]
recall5R = [0.0732, 0.0713, 0.0713, 0.0705]
recall10R = [0.1226, 0.1233, 0.1223, 0.1181]
ndcg5R = [0.3294, 0.3139, 0.3127, 0.3065]
ndcg10R = [0.2999, 0.2929, 0.2929, 0.2819]
precision5E = [0.3087, 0.3083, 0.315, 0.2931]
precision10E = [0.2687, 0.2676, 0.272, 0.2633]
recall5E = [0.0733, 0.0719, 0.0753, 0.0719]
recall10E = [0.123, 0.1227, 0.1241, 0.1228]
ndcg5E = [0.3189, 0.3258, 0.3289, 0.3072]
ndcg10E = [0.297, 0.3003, 0.3032, 0.2903]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度+中间层数对precision的影响', '嵌入维度+中间层数对recall的影响', '嵌入维度+中间层数对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## symmetric+graphsage

xpoints = ['32+2layer', '64+2layer', '32+4layer', '64+4layer',]

precision5R = [0.3154, 0.3038, 0.3132, 0.2859]
precision10R = [0.2785, 0.274, 0.2765, 0.2456]
recall5R = [0.0774, 0.072, 0.0731, 0.0686]
recall10R = [0.1296, 0.125, 0.1252, 0.1153]
ndcg5R = [0.3282, 0.3115, 0.3238, 0.2927]
ndcg10R = [0.3079, 0.2965, 0.3026, 0.2714]
precision5E = [0.3262, 0.3244, 0.3011, 0.294]
precision10E = [0.2765, 0.2801, 0.2678, 0.262]
recall5E = [0.0761, 0.0779, 0.0707, 0.0709]
recall10E = [0.1246, 0.1303, 0.1211, 0.1212]
ndcg5E = [0.3411, 0.3345, 0.3162, 0.3042]
ndcg10E = [0.3105, 0.3105, 0.2967, 0.2879]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度+中间层数对precision的影响', '嵌入维度+中间层数对recall的影响', '嵌入维度+中间层数对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
## symmetric+lightgcn

xpoints = ['32+2layer', '64+2layer', '32+4layer', '64+4layer',]

precision5R = [0.3114, 0.3007, 0.2819, 0.2447]
precision10R = [0.27, 0.2647, 0.2454, 0.2101]
recall5R = [0.074, 0.0705, 0.0675, 0.0609]
recall10R = [0.1235, 0.1222, 0.1126, 0.0989]
ndcg5R = [0.3213, 0.3161, 0.2889, 0.2485]
ndcg10R = [0.2984, 0.2955, 0.2701, 0.2301]
precision5E = [0.3181, 0.3311, 0.2908, 0.2667]
precision10E = [0.2783, 0.285, 0.264, 0.2365]
recall5E = [0.0753, 0.0797, 0.0674, 0.0644]
recall10E = [0.1278, 0.133, 0.119, 0.1087]
ndcg5E = [0.3291, 0.3455, 0.3014, 0.2767]
ndcg10E = [0.3071, 0.3184, 0.288, 0.2607]

fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
ydatas = [[(precision5E, precision10E), (precision5R, precision10R)], [(recall5E, recall10E), (recall5R, recall10R)], [(ndcg5E, ndcg10E), (ndcg5R, ndcg10R)]]
colors = [('blue','cyan'), ('green','magenta')]
line_styles = ['-', '--']
y_labels = [[('precision@5+transE', 'precision@10+transE'), ('precision@5+transR', 'precision@10+transR')], [('recall@5+transE', 'recall@10+transE'), ('recall@5+transR', 'recall@10+transR')], [('ndcg@5+transE', 'ndcg@10+transE'), ('ndcg@5+transR', 'ndcg@10+transR')]]
y_label = ('precision', 'recall', 'ndcg')
titles = ['嵌入维度+中间层数对precision的影响', '嵌入维度+中间层数对recall的影响', '嵌入维度+中间层数对ndcg的影响']

for j in range(3):
    axs[j].plot(xpoints, ydatas[j][0][0], c=colors[0][0], label=y_labels[j][0][0], linestyle=line_styles[0])
    axs[j].plot(xpoints, ydatas[j][0][1], c=colors[0][1], label=y_labels[j][0][1], linestyle=line_styles[0])
    axs[j].scatter(xpoints, ydatas[j][0][0], c=colors[0][0])
    axs[j].scatter(xpoints, ydatas[j][0][1], c=colors[0][1])
    
    axs[j].plot(xpoints, ydatas[j][1][0], c=colors[1][0], label=y_labels[j][1][0], linestyle=line_styles[1])
    axs[j].plot(xpoints, ydatas[j][1][1], c=colors[1][1], label=y_labels[j][1][1], linestyle=line_styles[1])
    axs[j].scatter(xpoints, ydatas[j][1][0], c=colors[1][0])
    axs[j].scatter(xpoints, ydatas[j][1][1], c=colors[1][1])
    
    axs[j].legend(loc='best')
    axs[j].grid(True, linestyle='--', alpha=0.5)
    axs[j].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[j].set_ylabel(y_label[j], fontdict={'size': 12}, rotation=90)
    axs[j].set_title(titles[j])
fig.autofmt_xdate()
plt.show()

# %%
xpoints = ['random-walk+gcn',]+ ['random-walk+graphsage',]+ ['random-walk+lightgcn',]+ ['symmetric+gcn',]+ ['symmetric+graphsage',]+ ['symmetric+lightgcn',]
colors = ['blue','cyan', 'green','magenta', 'red', 'yellow']
ypoints_precision = [[0.2734, 0.2935, 0.2794, 0.2736], [0.2848, 0.294, 0.2792, 0.279], [0.2855, 0.294, 0.2828, 0.2622], [0.2687, 0.2676, 0.272, 0.2633],[0.2765, 0.2801, 0.2678, 0.262],[0.2783, 0.285, 0.264, 0.2365]]
ypoints_precision_max = [max(i) for i in ypoints_precision]
ypoints_recall = [[0.1255, 0.1342, 0.1342, 0.1284],[0.1328, 0.1373, 0.1316, 0.1297], [0.1335, 0.1381, 0.1334, 0.1213],[0.123, 0.1227, 0.1241, 0.1228],[0.1246, 0.1303, 0.1211, 0.1212],[0.1278, 0.133, 0.119, 0.1087]]
ypoints_recall_max = [max(i) for i in ypoints_recall]
ypoints_ndcg = [[0.3096, 0.3259, 0.3114, 0.3075],[0.3195, 0.3231, 0.3157, 0.3083],[0.3231, 0.3279, 0.3118, 0.293], [0.297, 0.3003, 0.3032, 0.2903],[0.3105, 0.3105, 0.2967, 0.2879],[0.3071, 0.3184, 0.288, 0.2607]]
ypoints_ndcg_max = [max(i) for i in ypoints_ndcg]
ypoints = [ypoints_precision, ypoints_recall, ypoints_ndcg]
ypoints_max = [ypoints_precision_max, ypoints_recall_max, ypoints_ndcg_max]
y_label = ('precision', 'recall', 'ndcg')
titles = ['不同训练组合方式对precision影响的对比', '不同训练组合方式对recall影响的对比', '不同训练组合方式对ndcg影响的对比']
fig,axs = plt.subplots(nrows=3, ncols=1, figsize=(10,10), dpi=100)
for i in range(3):
    for j in range(6):
        xpoint = [xpoints[j]]*4
        axs[i].scatter(xpoint, ypoints[i][j], c=colors[j])
    for (s,t) in zip(xpoints, ypoints_max[i]):
        axs[i].text(s, t, t, ha='center', va='bottom', fontsize=10)
    axs[i].grid(True, linestyle='--', alpha=0.5)
    axs[i].set_xlabel("不同训练组合方式", fontdict={'size': 12})
    axs[i].set_ylabel(y_label[i], fontdict={'size': 12}, rotation=90)
    axs[i].set_title(titles[i])
fig.autofmt_xdate()
plt.show()

# %%
## 不同模型的对比分析

xpoints = [[16,32,64,128], [16,32,64,128], [32,64]]
ypoints_precision = [[0.2481, 0.2532, 0.2512, 0.2564], [0.2604, 0.2557, 0.2633, 0.2787],[0.2855, 0.294]]
ypoints_recall = [[0.1053, 0.1094, 0.1126, 0.1174],[0.1099, 0.1127, 0.1206, 0.1310],[0.1335, 0.1381]]
ypoints_ndcg = [[0.2686, 0.2829, 0.2779, 0.2949],[0.2816, 0.2881, 0.2898, 0.3171],[0.3231, 0.3279]]
ypoints = [ypoints_precision, ypoints_recall, ypoints_ndcg]
colors = ['red','green','blue']
y_label = ['precision', 'recall', 'ndcg']
y_labels = ['矩阵分解', '图谱嵌入', 'GNN']
titles = ['嵌入维度对不同模型precision的影响', '嵌入维度对不同模型recall的影响', '嵌入维度对不同模型ndcg的影响']
fig,axs = plt.subplots(nrows=1, ncols=3, figsize=(20,6), dpi=100)
for i in range(3):
    for j in range(3):
        axs[i].plot(xpoints[j], ypoints[i][j],label=y_labels[j], color = colors[j])
        axs[i].scatter(xpoints[j], ypoints[i][j], c=colors[j])
    axs[i].legend(loc='best')
    axs[i].grid(True, linestyle='--', alpha=0.5)
    axs[i].set_xlabel("embed_dim", fontdict={'size': 12})
    axs[i].set_ylabel(y_label[i], fontdict={'size': 12}, rotation=90)
    axs[i].set_title(titles[i])
fig.autofmt_xdate()
plt.show()
